# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj00709/EDA-project/blob/main/EDA_prjct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis Case Study - Crop production in INDIA
#
# ---
#
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0xtSeM3wGQkZrrTAXne5PnpVbXnKIsGYV4w&s)
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRpLV7ef1hWjV_m-RCGV9fLRIegMea_5_aalw&s)
#
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods. It requires the knowledge of statistics, visualization techniques and data analysis tools like Numpy, Pandas, Seaborn etc.

# %% [markdown]
# The following topics are covered in this project:
#
# - Downloading a dataset from an online source
# - Data preparation and cleaning with Pandas
# - Open-ended exploratory analysis and visualization
# - Asking and answering interesting questions
# - Summarizing inferences and drawing conclusions

# %% [markdown]
# ## INTRODUCTION
# Agriculture has been the backbone of the Indian economy and it will continue to
# remain so for a long time. It has to support almost 17 per cent of world population from 2.3 per cent of world geographical area and 4.2 per cent of world’s water resources
# The datasets contains required columns to understand rainfall and crop production over last 28 years in India. These datasets are collected from many official sites. The datasets have columns like temperature,rainfall,area,etc.. For more info check out Indian states agrictulture websites,mospi.gov.in and data.gov.in

# %%
# !pip install numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install opendatasets

# %%
# !pip install pandas

# %%
import opendatasets as od

# %%
url = 'https://drive.google.com/file/d/1m117MRgw_C1mbFdmxG75NxBCEOX6zQ2u/view'

# %%
url
# Out:
# 'https://drive.google.com/file/d/1m117MRgw_C1mbFdmxG75NxBCEOX6zQ2u/view'

# %%
od.download(url)
# Out:
# ...
# 736540it [00:00, 217769115.20it/s]
# Downloaded to  ./1m117MRgw_C1mbFdmxG75NxBCEOX6zQ2u

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
survey_raw_df = pd.read_csv('/content/drive/MyDrive/Crop_production.csv')

# %%
survey_raw_df
# Out:
#        Unnamed: 0      State_Name Crop_Type       Crop  Nitrogen  Phosphorus  \
# 0               0  andhra pradesh    kharif     cotton       120          40
# 1               1  andhra pradesh    kharif  horsegram        20          60
# 2               2  andhra pradesh    kharif      jowar        80          40
# 3               3  andhra pradesh    kharif      maize        80          40
# 4               4  andhra pradesh    kharif      moong        20          40
# ...           ...             ...       ...        ...       ...         ...
# 99844       99844     west bengal      rabi      wheat        60          30
# 99845       99845     west bengal    summer      maize        80          40
# 99846       99846     west bengal    summer       rice        80          40
# 99847       99847     west bengal      rabi       rice        80          40
# 99848       99848     west bengal      rabi    sesamum        30          15
#
# ...

# %%
survey_raw_df.columns
# Out:
# Index(['Unnamed: 0', 'State_Name', 'Crop_Type', 'Crop', 'Nitrogen',
#        'Phosphorus', 'potassium', 'pH', 'rainfall', 'temperature',
#        'Area_in_hectares', 'Production_in_tons', 'Yield_ton_per_hec'],
#       dtype='object')

# %%
survey_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99849 entries, 0 to 99848
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          99849 non-null  int64
#  1   State_Name          99849 non-null  object
#  2   Crop_Type           99849 non-null  object
#  3   Crop                99849 non-null  object
#  4   Nitrogen            99849 non-null  int64
#  5   Phosphorus          99849 non-null  int64
#  6   potassium           99849 non-null  int64
#  7   pH                  99849 non-null  float64
#  8   rainfall            99849 non-null  float64
#  9   temperature         99849 non-null  float64
#  10  Area_in_hectares    99849 non-null  float64
#  11  Production_in_tons  99849 non-null  float64
#  12  Yield_ton_per_hec   99849 non-null  float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 9.9+ MB

# %%
# Out:
# Unnamed: 0            0.0
# State_Name            0.0
# Crop_Type             0.0
# Crop                  0.0
# Nitrogen              0.0
# Phosphorus            0.0
# potassium             0.0
# pH                    0.0
# rainfall              0.0
# temperature           0.0
# Area_in_hectares      0.0
# Production_in_tons    0.0
# Yield_ton_per_hec     0.0
# dtype: float64

# %%
print(survey_raw_df.rainfall.unique())
# Out:
# [6.54340000e+02 2.88300000e+02 1.71266000e+03 2.41780000e+02
#  1.54376000e+03 1.27680000e+02 4.97880000e+02 2.16932000e+03
#  8.40460000e+02 8.72000000e+01 9.89800000e+01 1.02664000e+03
#  3.04140000e+03 2.87986000e+03 1.41460000e+02 7.90980000e+02
#  1.53400000e+01 8.10260000e+02 3.31880000e+02 4.13000000e+01
#  4.21140000e+02 5.16680000e+02 2.93360000e+02 1.24671500e+03
#  1.99212500e+02 1.57310000e+02 1.60323750e+03 2.81786000e+03
#  1.01149000e+03 7.34700000e+01 6.07480000e+02 7.01100000e+01
#  3.70900000e+01 7.14680000e+02 7.02459000e+02 1.35002500e+03
#  4.23745000e+02 5.62360000e+01 1.05024500e+03 2.35425100e+02
#  8.52431600e+01 7.42012400e+02 2.07550000e+02 7.05980000e+01
#  1.14522000e+03 1.67380000e+02 1.13700000e+02 1.42630000e+03
#  4.11520000e+02 6.65200000e+01 5.35780000e+02 5.10050000e+02
#  1.93800000e+01 5.56200000e+02 2.97660000e+02 8.84500000e+02
#  7.70440000e+02 9.89400000e+01 5.79750000e+02 7.53200000e+01
# ...

# %%
print(survey_raw_df.potassium.unique())
# Out:
# [ 20  40  30 140  65  90 120  50 100  45  60 150  85 200  10  70]

# %%
print(survey_raw_df.Nitrogen.unique())
# Out:
# [120  20  80  50  60  30 100 180  90  25  70  10  75  40 160]

# %%
print(survey_raw_df.Phosphorus.unique())
# Out:
# [ 40  60  30  15  20  50  75  10 125  65  45 100  70]

# %%
survey_raw_df[survey_raw_df.potassium == 150]
# Out:
#        Unnamed: 0 State_Name   Crop_Type      Crop  Nitrogen  Phosphorus  \
# 1621         1621  karnataka  whole year  cardamom        75          75
# 1651         1651  karnataka  whole year  cardamom        75          75
# 1699         1699  karnataka  whole year  cardamom        75          75
# 1712         1712  karnataka  whole year  cardamom        75          75
# 1758         1758  karnataka  whole year  cardamom        75          75
# ...           ...        ...         ...       ...       ...         ...
# 95331       95331  karnataka  whole year  cardamom        75          75
# 95477       95477  karnataka  whole year  cardamom        75          75
# 95525       95525  karnataka  whole year  cardamom        75          75
# 95686       95686  karnataka  whole year  cardamom        75          75
# 95756       95756  karnataka  whole year  cardamom        75          75
#
#        potassium    pH   rainfall  temperature  Area_in_hectares  \
# ...

# %%
survey_raw_df[survey_raw_df.Nitrogen == 120]
# Out:
#        Unnamed: 0      State_Name   Crop_Type    Crop  Nitrogen  Phosphorus  \
# 0               0  andhra pradesh      kharif  cotton       120          40
# 27             27  andhra pradesh      kharif  cotton       120          40
# 41             41  andhra pradesh      kharif  cotton       120          40
# 51             51  andhra pradesh      kharif  cotton       120          40
# 64             64  andhra pradesh      kharif  cotton       120          40
# ...           ...             ...         ...     ...       ...         ...
# 99556       99556     uttarakhand  whole year   onion       120          60
# 99570       99570     uttarakhand  whole year   onion       120          60
# 99573       99573     west bengal      kharif  cotton       120          40
# 99587       99587     west bengal      kharif  cotton       120          40
# 99719       99719     west bengal      kharif  cotton       120          40
#
# ...

# %%
survey_raw_df.describe()
# Out:
#          Unnamed: 0      Nitrogen    Phosphorus     potassium            pH  \
# count  99849.000000  99849.000000  99849.000000  99849.000000  99849.000000
# mean   49924.000000     69.816823     41.593656     42.037827      5.643624
# std    28824.067851     39.571469     15.056508     28.430263      0.505283
# min        0.000000     10.000000     10.000000     10.000000      3.820000
# 25%    24962.000000     50.000000     40.000000     20.000000      5.360000
# 50%    49924.000000     75.000000     40.000000     30.000000      5.540000
# 75%    74886.000000     80.000000     60.000000     50.000000      5.960000
# max    99848.000000    180.000000    125.000000    200.000000      7.000000
#
#            rainfall   temperature  Area_in_hectares  Production_in_tons  \
# count  99849.000000  99849.000000      99849.000000        9.984900e+04
# mean     701.151085     26.684154      16476.585668        3.776291e+04
# ...

# %%
survey_raw_df[survey_raw_df['rainfall']== 3322.060000]
# Out:
#        Unnamed: 0                   State_Name   Crop_Type         Crop  \
# 17728       17728  andaman and nicobar islands  whole year       banana
# 17729       17729  andaman and nicobar islands  whole year   cashewnuts
# 17730       17730  andaman and nicobar islands  whole year  sweetpotato
# 17731       17731  andaman and nicobar islands  whole year      tapioca
# 17734       17734  andaman and nicobar islands  whole year       banana
# ...           ...                          ...         ...          ...
# 92746       92746  andaman and nicobar islands  whole year      tapioca
# 92756       92756  andaman and nicobar islands  whole year       banana
# 92757       92757  andaman and nicobar islands  whole year      tapioca
# 92767       92767  andaman and nicobar islands  whole year       banana
# 92768       92768  andaman and nicobar islands  whole year      tapioca
#
#        Nitrogen  Phosphorus  potassium    pH  rainfall  temperature  \
# ...

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(survey_raw_df.State_Name	.unique())
# Out:
# ['andhra pradesh' 'arunachal pradesh' 'assam' 'bihar' 'goa' 'gujarat'
#  'haryana' 'jammu and kashmir' 'karnataka' 'kerala' 'madhya pradesh'
#  'maharashtra' 'manipur' 'meghalaya' 'mizoram' 'nagaland' 'odisha'
#  'punjab' 'rajasthan' 'tamil nadu' 'telangana' 'uttar pradesh'
#  'west bengal' 'chandigarh' 'dadra and nagar haveli' 'himachal pradesh'
#  'puducherry' 'sikkim' 'tripura' 'andaman and nicobar islands'
#  'chhattisgarh' 'uttarakhand' 'jharkhand']

# %%
survey_raw_df.State_Name.nunique()
# Out:
# 33

# %%
survey_raw_df.State_Name.value_counts().head(10)
# Out:
# State_Name
# uttar pradesh     12598
# madhya pradesh     9299
# karnataka          9224
# bihar              8608
# odisha             6244
# tamil nadu         6147
# rajasthan          5600
# assam              5525
# maharashtra        4243
# andhra pradesh     3802
# Name: count, dtype: int64

# %%
survey_raw_df.groupby('State_Name').State_Name.count().sort_values(ascending=True).head(10)
# Out:
# State_Name
# goa                             54
# chandigarh                      63
# dadra and nagar haveli          82
# andaman and nicobar islands    118
# sikkim                         290
# puducherry                     358
# tripura                        387
# mizoram                        530
# manipur                        679
# jammu and kashmir              802
# Name: State_Name, dtype: int64

# %%
top_state = survey_raw_df.State_Name.value_counts().head(5)
top_state
# Out:
# State_Name
# uttar pradesh     12598
# madhya pradesh     9299
# karnataka          9224
# bihar              8608
# odisha             6244
# Name: count, dtype: int64

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(8,4))
plt.xticks(rotation=75)
plt.title('Where do you live? ')
sns.barplot(x= top_state.index, y = top_state);

# %%
import plotly.express as px

# %%
fig = px.bar(x= top_state.index, y = top_state,color=top_state,color_discrete_map ={
    'uttar pradesh' : 'Blue',
    'madhya pradesh' : 'Green',
    'karnataka' : 'Red',
    'bihar' : 'Gold',
    'odisha': 'Yellow'})

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Rainfall

# %%
survey_raw_df.rainfall
# Out:
# 0        654.34
# 1        654.34
# 2        654.34
# 3        654.34
# 4        654.34
#           ...
# 99844    152.54
# 99845    182.50
# 99846    182.50
# 99847    152.54
# 99848    152.54
# Name: rainfall, Length: 99849, dtype: float64

# %%
sns.histplot(x= survey_raw_df.rainfall)
# Out:
# <Axes: xlabel='rainfall', ylabel='Count'>

# %%
import plotly.express as px

# %%
px.histogram(x= survey_raw_df.rainfall)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## crop

# %%
Crop = survey_raw_df.Crop.value_counts()
Crop
# Out:
# Crop
# rice           11430
# maize           9857
# moong           6855
# sesamum         6291
# wheat           6225
# rapeseed        5413
# jowar           5369
# potato          5324
# onion           5164
# sunflower       3682
# cotton          3157
# barley          3139
# ragi            2995
# sweetpotato     2899
# horsegram       2784
# turmeric        2562
# banana          2409
# soyabean        2325
# coriander       2253
# garlic          2138
# arecanut        1154
# tapioca         1134
# jute            1058
# cashewnuts       732
# blackpepper      571
# mango            330
# tomato           284
# brinjal          282
# papaya           281
# cardamom         237
# ladyfinger       217
# orange           146
# cabbage          125
# pineapple        117
# cauliflower      105
# grapes           104
# jackfruit         90
# drumstick         73
# cucumber          72
# bittergourd       67
# watermelon        59
# blackgram         58
# bottlegourd       58
# ...

# %%
survey_raw_df.Crop
# Out:
# 0           cotton
# 1        horsegram
# 2            jowar
# 3            maize
# 4            moong
#            ...
# 99844        wheat
# 99845        maize
# 99846         rice
# 99847         rice
# 99848      sesamum
# Name: Crop, Length: 99849, dtype: object

# %%
plt.title('Crop production')
plt.pie(Crop,labels=Crop.index,autopct='%1.2f%%',startangle=190);

# %%
survey_raw_df.columns
# Out:
# Index(['Unnamed: 0', 'State_Name', 'Crop_Type', 'Crop', 'Nitrogen',
#        'Phosphorus', 'potassium', 'pH', 'rainfall', 'temperature',
#        'Area_in_hectares', 'Production_in_tons', 'Yield_ton_per_hec'],
#       dtype='object')

# %% [markdown]
# ##

# %%
pH_level = survey_raw_df.pH.value_counts()
pH_level
# Out:
# pH
# 5.36    2922
# 5.42    2875
# 5.40    2859
# 5.38    2856
# 5.32    2834
#         ...
# 4.16      11
# 4.14      10
# 4.10       9
# 4.00       8
# 3.84       7
# Name: count, Length: 101, dtype: int64

# %%
sns.countplot(y = survey_raw_df.pH)
plt.xticks(rotation=75);

# %%
pH = survey_raw_df.groupby(['Nitrogen', 'potassium','Phosphorus']).size().unstack().fillna(0)

plt.figure(figsize=(12, 6))
pH.plot.area()
plt.title('Soil Type')
plt.xlabel('pH level')
plt.ylabel('percentage ')
plt.legend(title='levels')
plt.show()

# %%
px.scatter(survey_raw_df, x= 'Yield_ton_per_hec', y ='Production_in_tons', color= "Crop")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.scatterplot(data=survey_raw_df, x='Crop',y='pH')
